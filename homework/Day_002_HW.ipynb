# %%
import os
import numpy as np
import pandas as pd

# %%
# 設定 data_path
dir_data = './data/'

# %%
f_app = os.path.join(dir_data, 'application_train.csv')
print('Path of read in data: %s' % (f_app))
app_train = pd.read_csv(f_app)
# Out:
# Path of read in data: ./data/application_train.csv

# %% [markdown]
# ** 顯示前 5 列資料**

# %%
app_train.head()
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0      100002       1         Cash loans           M            N
# 1      100003       0         Cash loans           F            N
# 2      100004       0    Revolving loans           M            Y
# 3      100006       0         Cash loans           F            N
# 4      100007       0         Cash loans           M            N
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0               Y             0          202500.0    406597.5      24700.5
# 1               N             0          270000.0   1293502.5      35698.5
# 2               Y             0           67500.0    135000.0       6750.0
# 3               Y             0          135000.0    312682.5      29686.5
# 4               Y             0          121500.0    513000.0      21865.5
#
#               ...              FLAG_DOCUMENT_18 FLAG_DOCUMENT_19  \
# ...

# %% [markdown]
# **資料資訊**

# %%
print(app_train.info(),'\n')
print('number of column: %d /n number of row: %d'%(app_train.shape[1],app_train.shape[0]))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307511 entries, 0 to 307510
# Columns: 122 entries, SK_ID_CURR to AMT_REQ_CREDIT_BUREAU_YEAR
# dtypes: float64(65), int64(41), object(16)
# memory usage: 286.2+ MB
# None
#
# number of column: 122 /n number of row: 307511

# %% [markdown]
# **每個欄位相關性**

# %%
app_train.corr().round(3)
# Out:
#                              SK_ID_CURR  TARGET  CNT_CHILDREN  \
# SK_ID_CURR                        1.000  -0.002        -0.001
# TARGET                           -0.002   1.000         0.019
# CNT_CHILDREN                     -0.001   0.019         1.000
# AMT_INCOME_TOTAL                 -0.002  -0.004         0.013
# AMT_CREDIT                       -0.000  -0.030         0.002
# AMT_ANNUITY                      -0.000  -0.013         0.021
# AMT_GOODS_PRICE                  -0.000  -0.040        -0.002
# REGION_POPULATION_RELATIVE        0.001  -0.037        -0.026
# DAYS_BIRTH                       -0.001   0.078         0.331
# DAYS_EMPLOYED                     0.001  -0.045        -0.240
# DAYS_REGISTRATION                -0.001   0.042         0.183
# DAYS_ID_PUBLISH                  -0.000   0.051        -0.028
# OWN_CAR_AGE                       0.002   0.038         0.008
# FLAG_MOBIL                        0.003   0.001         0.001
# ...
