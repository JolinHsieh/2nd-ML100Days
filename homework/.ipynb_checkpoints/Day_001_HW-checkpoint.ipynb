# %% [markdown]
# ### **作業1：**
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
# [Data Set :TMDB 5000 Movie Dataset](https://www.kaggle.com/tmdb/tmdb-movie-metadata)
#
#  1.你選的這組資料為何重要
# 能夠掌握影視圈的最流行趨勢，哪些是受歡迎的演員？備受矚目的電影？進而提供推薦系統做為策略，帶入電影的商業模式
#
#  2.資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# IMDB電影資料庫，從The Movie Database(TMDb)的open data API抓取下來
#
#  3.蒐集而來的資料型態為何
# 電影類別、演員及導演名稱、TMDb投票數、收支等數個csv檔
#
#  4.這組資料想解決的問題如何評估
# 先用TMDb投票數轉換成好壞電影評分指標，並找出相似電影，透過相似電影建置推薦model並驗證，驗證方式則可透過交叉驗證方法來評估預測模型好壞。
#
#
#
# ### **作業2：**
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1.核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 假設 **改善叫車的等待時間** 會提升載客率，將提升業績。
#
# 2.資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 會影響叫車等待時間的因素，例如:叫車地點、時間、目的地、路線等
#
# 3.蒐集而來的資料型態為何
# csv或字串格式
#
# 4.你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 利用ML演算法，建立乘客次數及時間的模型，預測每天每個區域每個時段應該派遣等待的車輛數，再與實際的搭乘資料進行驗證，改善叫車效率。
#
#
# ### **作業3：**

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
def mean_squared_error(y,y_hat):
    """
    請完成這個 Function 後往下執行
    """
    MSE = sum((y-y_hat)**2) / len(y)
    return MSE

# %%
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 200.875
# The Mean absolute error is 11.628
